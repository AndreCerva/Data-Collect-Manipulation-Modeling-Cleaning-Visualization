# %% [markdown]
# # Ejercicios de Pandas
#
# Es momento de poner a pruebas tus nuevas habilidades. Utiliza el archivo <tt>population_by_county.csv</tt> para completar las tareas en negritas en la parte de abajo.
#
# <div class="alert alert-info" style="margin: 10px"><strong>NOTA:</strong>TODOS LOS EJERCICIOS PUDEN REALIZARSE CON UNA SOLA LINEA DE CODIGO DE PANDAS.</div>
#
# <div class="alert alert-danger" style="margin: 10px"><strong>¡NOTA IMPORTANTE!</strong>Asegurate de no ejecutar las celdas directamente arriva de la salida mostrada, <br>de otra forma sobreescribiras la salida de ejemplo!</div>

# %% [markdown]
# #### 1. Importa pandas y lee el archivo <tt>population_by_county.csv</tt> en una dataframe llamado <tt>pop</tt>.

# %%
import pandas as pd
import numpy as np

# %%
population = pd.read_csv("./datasets/population_by_country_2020.csv")

# %% [markdown]
# #### 2. Muestra el head del dataframe.

# %%
# ESCRIBE TU CÓDIGO AQUI
population.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1440297825        0.39 %     5540090
# 1                   India         1382345085        0.99 %    13586631
# 2           United States          331341050        0.59 %     1937734
# 3               Indonesia          274021604        1.07 %     2898047
# 4                Pakistan          221612785        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# ...

# %% [markdown]
# #### 3. ¿Cuáles son los nombres de las columnas?

# %%
population.columns
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %% [markdown]
# <strong>4. ¿Cuántos estados están representados en este dataset?</strong> <em>Nota: los datos incluyen el distrito de Columbia</em>

# %%
len(population["Country (or dependency)"].unique())
# Out:
# 235

# %% [markdown]
# #### 5. Obtén una listo o arreglo de todos los estados en el dataset

# %%
population["Country (or dependency)"].unique()
# Out:
# array(['China', 'India', 'United States', 'Indonesia', 'Pakistan',
#        'Brazil', 'Nigeria', 'Bangladesh', 'Russia', 'Mexico', 'Japan',
#        'Ethiopia', 'Philippines', 'Egypt', 'Vietnam', 'DR Congo',
#        'Turkey', 'Iran', 'Germany', 'Thailand', 'United Kingdom',
#        'France', 'Italy', 'Tanzania', 'South Africa', 'Myanmar', 'Kenya',
#        'South Korea', 'Colombia', 'Spain', 'Uganda', 'Argentina',
#        'Algeria', 'Sudan', 'Ukraine', 'Iraq', 'Afghanistan', 'Poland',
#        'Canada', 'Morocco', 'Saudi Arabia', 'Uzbekistan', 'Peru',
#        'Angola', 'Malaysia', 'Mozambique', 'Ghana', 'Yemen', 'Nepal',
#        'Venezuela', 'Madagascar', 'Cameroon', "Côte d'Ivoire",
#        'North Korea', 'Australia', 'Niger', 'Taiwan', 'Sri Lanka',
#        'Burkina Faso', 'Mali', 'Romania', 'Malawi', 'Chile', 'Kazakhstan',
#        'Zambia', 'Guatemala', 'Ecuador', 'Syria', 'Netherlands',
#        'Senegal', 'Cambodia', 'Chad', 'Somalia', 'Zimbabwe', 'Guinea',
# ...

# %% [markdown]
# #### 6. ¿Cuáles son el pormedio de dades que más se repiten?

# %%
population['Med. Age'].value_counts().head()
# Out:
# N.A.    34
# 19      14
# 28      12
# 43      11
# 32      11
# Name: Med. Age, dtype: int64

# %% [markdown]
# #### 7. ¿Cuáles son los 5 condados con mayor población?

# %%
population.sort_values(by=['Population (2020)'], ascending=False).head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1440297825        0.39 %     5540090
# 1                   India         1382345085        0.99 %    13586631
# 2           United States          331341050        0.59 %     1937734
# 3               Indonesia          274021604        1.07 %     2898047
# 4                Pakistan          221612785        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# ...

# %% [markdown]
# #### 8. ¿Cuaĺes son los 5 países con más densidad por km?

# %%
population.iloc[population['Density (P/Km²)'].sort_values(ascending=False)[:5].index]
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 213                  Monaco              39290        0.71 %         278
# 166                   Macao             650846        1.39 %        8890
# 113               Singapore            5858322        0.79 %       46005
# 103               Hong Kong            7507523        0.82 %       60827
# 218               Gibraltar              33689       -0.03 %         -10
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 213            26337                1             NaN       N.A.     N.A.
# 166            21645               30          5000.0        1.2       39
# 113             8358              700         27028.0        1.2       42
# 103             7140             1050         29308.0        1.3       45
# 218             3369               10             NaN       N.A.     N.A.
#
#     Urban Pop % World Share
# 213        N.A.      0.00 %
# ...

# %% [markdown]
# #### 9. ¿Cuántos condados tenían una población mayor a un millón de habitantes?

# %%
population['Population (2020)'][population['Population (2020)']<1_000_000].index.size
# Out:
# 76

# %% [markdown]
# #### 10. ¿Cuales son estos condados con una población mayor a un millón de habitantes?

# %%
population.iloc[population['Population (2020)'][population['Population (2020)']>1_000_000].index]
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1440297825        0.39 %     5540090
# 1                     India         1382345085        0.99 %    13586631
# 2             United States          331341050        0.59 %     1937734
# 3                 Indonesia          274021604        1.07 %     2898047
# 4                  Pakistan          221612785        2.00 %     4327022
# 5                    Brazil          212821986        0.72 %     1509890
# 6                   Nigeria          206984347        2.58 %     5175990
# 7                Bangladesh          164972348        1.01 %     1643222
# 8                    Russia          145945524        0.04 %       62206
# 9                    Mexico          129166028        1.06 %     1357224
# 10                    Japan          126407422       -0.30 %     -383840
# 11                 Ethiopia          115434444        2.57 %     2884858
# ...

# %% [markdown]
# #### 11. ¿Cuantos paises no tienen una 'A' en su nombre?

# %%
population['Country (or dependency)'].str.extract(".*(A).*").notnull().sum().loc[0]
# Out:
# 18

# %% [markdown]
# # ¡Buen trabajo!
